# %% [markdown]
# # Data analysis: Weather
# In the file `weather_dataset.csv` you find weather data for various cities. It is up to you to clean and analyse this data. Use the provided code fields under the tasks to write down your code.

# %% [markdown]
# Import the necessary packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# * Import the weather dataset into a DataFrame named `df_weather`
# * Inspect the DataFrame by showing the first 10 rows (do not use slicing for this).

# %%
#Import and inspect
df_weather = pd.read_csv("weather_dataset.csv")
df_weather.head(10)
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1                  8            0.89          1.0286
# 1  20000102      1                  8            0.87          1.0318
# 2  20000103      1                  5            0.81          1.0314
# 3  20000104      1                  7            0.79          1.0262
# 4  20000105      1                  5            0.90          1.0246
# 5  20000106      1                  3            0.85          1.0244
# 6  20000107      1                  8            0.84          1.0267
# 7  20000108      1                  4            0.79          1.0248
# 8  20000109      1                  8            0.88          1.0243
# 9  20000110      1                  8            0.91          1.0337
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                    0.20                 0.03             0.0
# 1                    0.25                 0.00             0.0
# ...

# %% [markdown]
# * Change the dates in the DATE column to pandas datetime objects.
# * Only include the rows with data from 2009

# %%
#datetime objects, year 2009
df_weather["DATE"] = pd.to_datetime(df_weather["DATE"], format="%Y%m%d")

date2 = pd.to_datetime("2009-01-01")
# df_weather = df_weather[df_weather["DATE"] >= date2]
df_weather = df_weather.loc[df_weather["DATE"].dt.year == 2009]

df_weather
# type(df_weather["DATE"][0].year)
# df_weather = df_weather[(df_weather["DATE"] - date2).days > 0]
# df_weather = df_weather[(df_weather["DATE"].year - 2009) > 0]
# df_weather = df_weather[date for date in df_weather["DATE"] if (date - date2).days > 0]



# date = df_weather["DATE"][0]

# print(type(date))
# print(type(date2))
# print(type((date - date2).days))
# Out:
#            DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 3288 2009-01-01      1                  4            0.84          1.0284
# 3289 2009-01-02      1                  8            0.89          1.0262
# 3290 2009-01-03      1                  5            0.72          1.0263
# 3291 2009-01-04      1                  4            0.75          1.0239
# 3292 2009-01-05      1                  8            0.84          1.0197
# ...         ...    ...                ...             ...             ...
# 3648 2009-12-27     12                  7            0.80          1.0118
# 3649 2009-12-28     12                  7            0.82          1.0084
# 3650 2009-12-29     12                  7            0.92          1.0028
# 3651 2009-12-30     12                  8            0.92          0.9979
# 3652 2009-12-31     12                  7            0.93          0.9958
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# ...

# %% [markdown]
# * Remove the rows with NaN values.

# %%
df_weather.dropna(inplace=True)

# %% [markdown]
# * Create 4 different DataFrames, one for each of the following cities: Basel, Oslo, Roma and Maastricht. Name them `df_Basel`, `df_Oslo`, `df_Roma` and `df_Maastricht` respectively.
# * Each dataframe should include the columns with the dates and months and the columns with the data of the corresponding city.

# %%
cities = ["BASEL", "OSLO", "ROMA", "MAASTRICHT"]
df_cities = {}
for city in cities:
    df_cities[city] = df_weather[["DATE", "MONTH"] + [column for column in df_weather.columns if city in column]]

df_Basel = df_cities["BASEL"]
df_Oslo = df_cities["OSLO"]
df_Roma = df_cities["ROMA"]
df_Maastricht = df_cities["MAASTRICHT"]

# df_basel = df_weather[["DATE", "MONTH", "BASEL_cloud_cover", "BASEL_humidity", "BASEL_pressure", "BASEL_global_radiation", "BASEL_precipitation", "BASEL_sunshine", "BASEL_temp_mean", "BASEL_temp_min", "BASEL_temp_max"]]
# df_oslo = df_weather[["DATE", "MONTH", "OSLO_cloud_cover", "OSLO_humidity", "OSLO_pressure", "OSLO_global_radiation", "OSLO_precipitation", "OSLO_sunshine", "OSLO_temp_mean", "OSLO_temp_min", "OSLO_temp_max"]]
# df_roma = df_weather[["DATE", "MONTH", "ROMA_cloud_cover", "ROMA_humidity", "ROMA_pressure", "ROMA_global_radiation", "ROMA_sunshine", "ROMA_temp_mean", "ROMA_temp_min", "ROMA_temp_max"]]
df_maastricht = df_weather[["DATE", "MONTH", "MAASTRICHT_cloud_cover", "MAASTRICHT_humidity", "MAASTRICHT_pressure", "MAASTRICHT_global_radiation", "MAASTRICHT_precipitation", "MAASTRICHT_sunshine", "MAASTRICHT_temp_mean", "MAASTRICHT_temp_min", "MAASTRICHT_temp_max"]]

# %% [markdown]
# ### Maastricht
# Plot a figure displaying following information of the temperature measurements over time done in Maastricht:
# * Temperature in °C is displayed on the y-axis
# * Mean temperature in orange
# * Max temperature in red
# * Min temperature in blue
# * Display a legend with appropriate labels, indicating which data is shown
# * Ensure proper axis labels and a title are included
# * On the x-axis, ensure there are indications for every month, labeled with the abbreviation of the month in English (Jan, Feb, March etc.)

# %%
def get_month_name(date):
    if date.month == 1:
        return "Jan"
    if date.month == 2:
        return "Feb"
    if date.month == 3:
        return "March"
    if date.month == 4:
        return "Apr"
    if date.month == 5:
        return "May"
    if date.month == 6:
        return "June"
    if date.month == 7:
        return "July"
    if date.month == 8:
        return "Aug"
    if date.month == 9:
        return "Sep"
    if date.month == 10:
        return "Oct"
    if date.month == 11:
        return "Nov"
    if date.month == 12:
        return "Dec"

# %%
#Maastricht
x_names = ["Jan", "Feb", "March", "April", "May", "June", "July", "Aug", "Oct", "Nov", "Dec", "Jan"]

plt.figure(figsize=(10, 6))



# plt.plot(df_maastricht["DATE"], df_maastricht["MAASTRICHT_temp_mean"], label="Mean temperature", color="orange")
# plt.plot(df_maastricht["DATE"], df_maastricht["MAASTRICHT_temp_max"], label="Minimal temperature", color="red")
# plt.plot(df_maastricht["DATE"], df_maastricht["MAASTRICHT_temp_min"], label="Maximal temperature", color="blue")

plt.plot(df_Maastricht["DATE"], df_Maastricht["MAASTRICHT_temp_mean"], label="Mean temperature", color="orange")
plt.plot(df_Maastricht["DATE"], df_Maastricht["MAASTRICHT_temp_max"], label="Minimal temperature", color="red")
plt.plot(df_Maastricht["DATE"], df_Maastricht["MAASTRICHT_temp_min"], label="Maximal temperature", color="blue")
plt.xticks(ticks=[f"2009-{month:02}" for month in range(1, 13)], labels=("Jan", "Feb", "March", "April", "May", "June", "July", "Aug", "Sep", "Oct", "Nov", "Dec"))


# plt.plot([get_month_name(date) for date in df_Maastricht["DATE"]], df_Maastricht["MAASTRICHT_temp_mean"], label="Average temperature", color="orange")
# plt.plot([get_month_name(date) for date in df_Maastricht["DATE"]], df_Maastricht["MAASTRICHT_temp_max"], label="Maximal temperature", color="red")
# plt.plot([get_month_name(date) for date in df_Maastricht["DATE"]], df_Maastricht["MAASTRICHT_temp_min"], label="Minimal temperature", color="blue")

plt.xlabel("Month")
plt.ylabel("Temperature")

plt.title("Temperature in Maastricht over the year")

# print(df_Maastricht["DATE"].iloc[0].month)
plt.legend()

# %% [markdown]
# ### Mean temperatures
# Create a new graph and plot the mean temperatures over time of the cities for which you created seperate dataframes. Temperatures are in degrees Celcius and displayed on the y-axis.
# * Maastricht in orange
# * Roma in red
# * Basel in green
# * Oslo in blue
# * Display a legend with appropriate labels so it is clear what data is shown
# * Ensure proper axis labels and a title are included
# * On the x-axis, ensure indications for every month, labeled with the abbreviation of the month in English (Jan, Feb, March etc.)
# * Show a grid

# %%
#Maastricht
x_names = ["Jan", "Feb", "March", "April", "May", "June", "July", "Aug", "Oct", "Nov", "Dec", "Jan"]

plt.figure(figsize=(10, 6))



# plt.plot(df_maastricht["DATE"], df_maastricht["MAASTRICHT_temp_mean"], label="Mean temperature", color="orange")
# plt.plot(df_maastricht["DATE"], df_maastricht["MAASTRICHT_temp_max"], label="Minimal temperature", color="red")
# plt.plot(df_maastricht["DATE"], df_maastricht["MAASTRICHT_temp_min"], label="Maximal temperature", color="blue")

plt.plot(df_Maastricht["DATE"], df_Maastricht["MAASTRICHT_temp_mean"], label="Maastricht", color="orange")
plt.plot(df_Roma["DATE"], df_Roma["ROMA_temp_mean"], label="Roma", color="red")
plt.plot(df_Basel["DATE"], df_Basel["BASEL_temp_mean"], label="Basel", color="blue")
plt.plot(df_Oslo["DATE"], df_Oslo["OSLO_temp_mean"], label="Oslo", color="green")
plt.xticks(ticks=[f"2009-{month:02}" for month in range(1, 13)], labels=("Jan", "Feb", "March", "April", "May", "June", "July", "Aug", "Sep", "Oct", "Nov", "Dec"))

# 2009-01
# 2009-03


# plt.plot([get_month_name(date) for date in df_Maastricht["DATE"]], df_Maastricht["MAASTRICHT_temp_mean"], label="Average temperature", color="orange")
# plt.plot([get_month_name(date) for date in df_Maastricht["DATE"]], df_Maastricht["MAASTRICHT_temp_max"], label="Maximal temperature", color="red")
# plt.plot([get_month_name(date) for date in df_Maastricht["DATE"]], df_Maastricht["MAASTRICHT_temp_min"], label="Minimal temperature", color="blue")

plt.xlabel("Month")
plt.ylabel("Temperature")

plt.title("Mean temperature in different cities")

# print(df_Maastricht["DATE"].iloc[0].month)
plt.legend()
plt.grid()

# %% [markdown]
# ___

# %% [markdown]
# Check your work thouroughly and ensure you did all the tasks.
# There are no tests provided for this data analysis exercise. Ensure you used the right names.

# %% [markdown]
# ___
